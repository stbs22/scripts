# %%
import numpy as np, cv2
import matplotlib.pyplot as plt
cmap='gray'

# %%
def mk_plots(x=10,y=15,nr=1,nc=3,dpi=120,axis="on"):
    fig, ax = plt.subplots(nrows=nr, ncols=nc, dpi=dpi)
    fig.set_size_inches(x,y)

    if nr != 1: [[x.axis(axis) for x in y] for y in ax]
    else: [x.axis(axis) for x in ax]
    
    return ax

# %%
t = np.arange(-5, 11, 0.01)
s = np.sinc(t)

plt.plot(t, s)
plt.xticks(np.arange(-6,11,1))
plt.show()

# %%
leo = cv2.imread("leo.png",0)
filas, columnas = leo.shape
plt.hist(leo.reshape(filas*columnas,-1), bins= 100)
plt.show()
